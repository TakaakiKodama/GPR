# %%
include("./Functions.jl")
using .GPLM
using Random
using Plots
using LinearAlgebra
using Distributions
gr()
# Out:
# Plots.GRBackend()

# %%
k(x,x_)=(x[1]x_[1]+x[2]x_[2]+1)^2
# Out:
# k (generic function with 1 method)

# %%
Φ(x)=[x[1]^2 x[2]^2 (x[1] * x[2])*√2 x[1]*√2 x[2]*√2 1]
# Out:
# Φ (generic function with 1 method)

# %%
f(x)=[sin(x[1]) cos(x[2]) ]
# Out:
# f (generic function with 1 method)

# %%
n(x)=[0.1x[1] 0.05x[2]]
X,Y=GPLM.ToyData(f,2,2,min=0,max=π,messiness=n, N=100)
# Out:
# MethodError: no method matching +(::Float64, ::Adjoint{Float64,Array{Float64,1}})
# Closest candidates are:
#   +(::Any, ::Any, !Matched::Any, !Matched::Any...) at operators.jl:529
#   +(::Float64, !Matched::Float64) at float.jl:395
#   +(::AbstractFloat, !Matched::Bool) at bool.jl:106
#   ...
#
# Stacktrace:
#  [1] #ToyData#1(::Int64, ::Irrational{:π}, ::Int64, ::typeof(n), ::typeof(Main.GPLM.ToyData), ::typeof(f), ::Int64, ::Int64) at /Users/tk/Desktop/MLP/Functions.jl:13
#  [2] (::getfield(Main.GPLM, Symbol("#kw##ToyData")))(::NamedTuple{(:min, :max, :messiness, :N),Tuple{Int64,Irrational{:π},typeof(n),Int64}}, ::typeof(Main.GPLM.ToyData), ::Function, ::Int64, ::Int64) at ./none:0
#  [3] top-level scope at In[31]:2

# %%
Y[1,:]
# Out:
# UndefVarError: Y not defined
#
# Stacktrace:
#  [1] top-level scope at In[6]:1

# %%
plot(X[:,1],Y[:,1],seriestype=:scatter)
plot!(X[:,2],Y[:,2],seriestype=:scatter)
# Out:
# UndefVarError: X not defined
#
# Stacktrace:
#  [1] top-level scope at In[7]:1

# %%
K=zeros(size(Y,1),size(Y,1))
for i in 1:size(Y,1)
    for j in 1:i
        K[i,j]=K[j,i]
    end
    for j in i:size(Y,1)
        K[i,j]=(Φ(Y[i,:])Φ(Y[j,:])')[1]
    end
end
# Out:
# UndefVarError: Y not defined
#
# Stacktrace:
#  [1] top-level scope at In[8]:1

# %%
K
# Out:
# UndefVarError: K not defined
#
# Stacktrace:
#  [1] top-level scope at In[9]:1

# %%
K_=zeros(size(Y,1),size(Y,1))
for i in 1:size(Y,1)
    for j in 1:size(Y,1)
        K_[i,j]=k(Y[i,:],Y[j,:])
    end
end
# Out:
# UndefVarError: Y not defined
#
# Stacktrace:
#  [1] top-level scope at In[10]:1

# %%
K_
# Out:
# UndefVarError: K_ not defined
#
# Stacktrace:
#  [1] top-level scope at In[11]:1

# %%
G(x,x_,θ1,θ2)=θ1*exp(-(x-x_)*(x-x_)'/θ2)
# Out:
# G (generic function with 1 method)

# %%
x=[i for i in 0:0.1:10]
x_=5
θ1=1
θ2=1
y=[G(i,x_,θ1,θ2) for i in x]
plot(x,y)

# %%
G(x,x_)=GPLM.GaussianKernel(x,x_,th1=1,th2=1)
x=[i for i in 1:1:4]
K=GPLM.KernelMatrix(x,G)
y=cholesky(K).L*randn(length(x))
plot(x,y)

# %%
x=[i for i in 1:0.5:4]
K=GPLM.KernelMatrix(x,G)
y=cholesky(K).L*randn(length(x))
plot!(x,y)

# %%
x=[i for i in 1:0.2:4]
K=GPLM.KernelMatrix(x,G)
y=cholesky(K).L*randn(length(x))
plot!(x,y)

# %%
X=vcat([[i i] for i in 1:0.2:4]...)
K=GPLM.KernelMatrix(X,G)
# Out:
# 16×16 Array{Float64,2}:
#  1.0       0.961558  0.863075  0.743376  …  0.500001  0.5       0.5
#  -0.20213838031199088
#   3.471690656685409
#  -1.4837375174473837
#   0.34354970469453416
#   1.1015870741056908
#  -2.911183581481725
#   0.05066043990871652
#   1.035638217962127
#   1.060945900868579
#   0.025567678799591223
#   0.27182958694593395

# %%
μ=[]
σ=[]
for i in 0:0.1:2π
    k_=[k(j,i) for j in X]
    s=k(i,i)
    mu=(k_'*yy)[1]
    var=√(abs(s-(k_'*inv(K)*k_)[1]))
    push!(μ,mu)
    push!(σ,var)
end
plot!(0:0.1:2π,μ)
plot!(0:0.1:2π,μ+σ)
plot!(0:0.1:2π,μ-σ)

# %%
σ
# Out:
# 63-element Array{Any,1}:
#  0.23173879629904523
#  0.17925493668596065
#  0.14958523910727192
#  0.14186162238218483
#  0.14663857825946042
#  0.15393911343769595
#  0.15862125493439502
#  0.15946894121725677
#  0.15722926882962512
#  0.15326148735161943
#  0.14872593018865732
#  0.14422308775531173
#  0.13984670592044737
#  ⋮
#  0.1470788660488226
#  0.1514551212631628
#  0.153331330951268
#  0.1524735432342992
#  0.1492438632217728
#  0.1442101436811225
#  0.13808666807914932
#  0.1324800293725089
#  0.13150213592821103
#  0.142542926150936
#  0.17255837437844498
#  0.22275661794730978

# %%
(μ,σ,K,K_,yy)=GPLM.GaussianProcessRegression(X,Y,k,x_test=[i for i in 0:0.1:2π],observationn_noise=0.01)
# Out:
# (Any[-0.3020894830162071, -0.07183926299734367, 0.11286482821873278, 0.24644324382523308, 0.33537838490907745, 0.39644482555564764, 0.4523526297098144, 0.5258127844039038, 0.633542171727072, 0.7818234220420806  …  -4.718125395398118, -4.586080803815776, -4.319424132973168, -3.925763821355801, -3.4293964314141974, -2.8668456793436476, -2.280480734138102, -1.711709789158654, -1.1951568699420605, -0.7548220237529506], Any[0.0726085163815894, 0.044958005847722346, 0.03585977376069949, 0.03710284751110188, 0.039861597629939294, 0.041600618132253304, 0.04218621828359248, 0.04177614468240075, 0.040639945525787514, 0.03923926110039625  …  0.041493667546241716, 0.04021856818136091, 0.038079339575217565, 0.03617931439839925, 0.03539653430959776, 0.035405903312667616, 0.034946101237471425, 0.034738523073212825, 0.042523315129261656, 0.06829492411131227], [1.01 1.4349635972615309e-5 … 0.3796318225029094 0.0006068860829990787; 1.4349635972615309e-5 1.01 … 0.003897835223545991 0.6827009358472894; … ; 0.3796318225029094 0.003897835223545991 … 1.01 0.04886133751061861; 0.0006068860829990787 0.6827009358472894 … 0.04886133751061861 1.01], [90.11666061416072 -0.00011722654107466576 … 1.3003419920316808 -0.002887143261471777; -0.00011722654107602405 85.05308587698963 … -0.2138707171561831 -0.18548743879414498; … ; 1.300341992031756 -0.21387071715615977 … 90.06821250007545 0.31499524101794774; -0.002887143261466029 -0.18548743879345914 … 0.31499524101815796 89.12616681829032], [2.9733657290010687, -95.06997434257258, -1.5887832060073386, -45.99364279927914, -62.591193638525354, -106.00385905022597, 275.88993364992336, -129.10455258683746, -130.84467708647065, -46.84195292608287  …  63.273612433444484, -36.174879912186924, 11.793100895194039, 21.275029144919436, -49.02402118629581, 6.748808778726951, 15.550436691759685, 11.891698849697825, 5.056085413055924, -2.3727743120668947])

# %%
x_test=[i for i in 0:0.1:2π]
x=[i for i in 0:0.1:2π]
y=[f(i) for i in x]
plot(x,y)
plot!(x_test,μ)
plot!(X,Y,seriestype=:scatter)
plot!(x_test,μ+2 .*σ)
plot!(x_test,μ-2 .*σ)

# %%
plot(x,y)
plot!(x_test,μ)
plot!(x_test,σ)
plot!(x_test,μ+2 .*σ)
plot!(x_test,μ-2 .*σ)
